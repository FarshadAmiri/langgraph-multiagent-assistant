# %%
import os
os.chdir(r"D:\Git_repos\MAS_playground")
import api_call_functions

api_key = "tpsg-tMLXhjGxa2E18Pw6vCRINcgtD3PblTI"
bot_id = "a7d0e9dd-9ef9-4f91-8970-8f07b1a61283"
session_id = "e93dc5f2-2413-4bfb-b33a-0977c4c9b393"

# %% [markdown]
# Work with Metis API

# %%
from openai import OpenAI
import requests


def openai_call(sys_prompt, user_prompt, api_key, base_url="https://api.metisai.ir/openai/v1"):
    client = OpenAI(api_key=api_key, base_url=base_url)

    response = client.chat.completions.create(
        model="GPT-4o-mini",
        messages=[
            {"role": "system", "content": sys_prompt},
            {"role": "user", "content": user_prompt}
        ]
    )
    return response.choices[0].message.content


def start_chat(api_key, bot_id, user_prompt):
    url = "https://api.metisai.ir/api/v1/chat/session"
    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json"
    }
    payload = {
        "botId": bot_id,
        "user": None,
        "initialMessages": [
            {
                "type": "USER",
                "content": user_prompt
            }
        ]
    }

    response = requests.post(url, headers=headers, json=payload)
    
    if response.status_code != 200:
        print("❌ Metis API Error:")
        print(f"Status Code: {response.status_code}")
        print(f"Response Text: {response.text}")
        raise Exception("Failed to get response from Metis API.")

    return response.json()


def continue_session(api_key, session_id, user_prompt):
    url = f"https://api.metisai.ir/api/v1/chat/session/{session_id}/message"
    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json"
    }
    payload = {
        "message": {
            "content": user_prompt,
            "type": "USER"
        }
    }

    response = requests.post(url, headers=headers, json=payload)

    if response.status_code != 200:
        print("❌ Error sending message:")
        print(f"Status Code: {response.status_code}")
        print(f"Response: {response.text}")
        raise Exception("Failed to send message to Metis session.")

    return response.json()


def metis_call(api_key, bot_id, user_prompt):
    url = "https://api.metisai.ir/api/v1/chat/session"
    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json"
    }
    payload = {
        "botId": bot_id,
        "user": None,
        "initialMessages": [
            {
                "type": "USER",
                "content": user_prompt
            }
        ]
    }

    response = requests.post(url, headers=headers, json=payload)
    
    if response.status_code != 200:
        print("❌ Metis API Error:")
        print(f"Status Code: {response.status_code}")
        print(f"Response Text: {response.text}")
        raise Exception("Failed to get response from Metis API.")

    return response.json()

# %%
def start_chat(api_key, bot_id, user_prompt):
    url = "https://api.metisai.ir/api/v1/chat/session"
    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json"
    }
    payload = {
        "botId": bot_id,
        "user": None,
        "initialMessages": [
            {
                "type": "USER",
                "content": user_prompt
            }
        ]
    }

    response = requests.post(url, headers=headers, json=payload)
    
    if response.status_code != 200:
        print("❌ Metis API Error:")
        print(f"Status Code: {response.status_code}")
        print(f"Response Text: {response.text}")
        raise Exception("Failed to get response from Metis API.")

    return response.json()


session_id = start_chat(api_key, bot_id, "")["id"]
# Out:
# {'id': '61af475d-f2c1-492c-90d6-1f98fa1a1442',
#  'botId': 'a7d0e9dd-9ef9-4f91-8970-8f07b1a61283',
#  'user': None,
#  'messages': [{'id': 'dd250c4c-f31e-43da-93c4-f23d0bd9015f',
#    'type': 'USER',
#    'content': 'hey',
#    'input': None,
#    'actions': None,
#    'tasks': None,
#    'attachments': None,
#    'timestamp': 1760782413886,
#    'finishReason': 'STOP',
#    'citations': None,
#    'toolCalls': None,
#    'rag': None,
#    'billing': None,
#    'googleSearchQuery': None}],
#  'startDate': 1760782413859,
#  'lastUpdateDate': 1760782413859,
#  'headline': None}

# %%
session_id = "61af475d-f2c1-492c-90d6-1f98fa1a1442"
api_key = "tpsg-tMLXhjGxa2E18Pw6vCRINcgtD3PblTI"


def continue_session(api_key, session_id, user_prompt):
    url = f"https://api.metisai.ir/api/v1/chat/session/{session_id}/message"
    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json"
    }
    payload = {
        "message": {
            "content": user_prompt,
            "type": "USER"
        }
    }

    response = requests.post(url, headers=headers, json=payload)

    if response.status_code != 200:
        print("❌ Error sending message:")
        print(f"Status Code: {response.status_code}")
        print(f"Response: {response.text}")
        raise Exception("Failed to send message to Metis session.")

    return response.json()

user_prompt = "what will be the most influential advancement and technology that human being can ever attain? what is your opinion?"


res = continue_session(api_key, session_id, user_prompt)

# %%
answer = res["content"]
answer
# Out:
# 'That\'s a HUGE question! There\'s no single right answer, as "influential" can be interpreted in many ways (positive, negative, long-lasting, transformative, etc.). However, I can give you a few contenders, along with arguments for why they might be the *most* influential:\n\n**1. Artificial General Intelligence (AGI):**\n\n*   **What it is:** AI that can understand, learn, and apply knowledge across a wide range of domains, at least as well as a human. Think AI that\'s not just good at chess or image recognition, but can solve complex problems, invent new technologies, and understand human emotions.\n*   **Why it could be the *most* influential:** If achieved, AGI would fundamentally change everything.  It could accelerate scientific discovery, solve global challenges like climate change and disease, and even redefine what it means to be human. The societal and economic implications are almost unimaginable. The potential for both immense good and immense harm makes it incredibly influential, even if terrifying to some.\n*   **Potential Downsides:** Existential risk (loss of control, unintended consequences), massive job displacement, weaponization.\n\n**2. Controlled Fusion Power:**\n\n*   **What it is:**  Harnessing the energy of nuclear fusion to create virtually limitless, clean energy.  This would involve fusing atoms together (like the sun does) rather than splitting them (like nuclear fission).\n*   **Why it could be the *most* influential:**  Solves the energy crisis.  Provides a clean, sustainable, and abundant energy source, drastically reducing dependence on fossil fuels and mitigating climate change. This alone would reshape geopolitics, economics, and global development.\n*   **Potential Downsides:**  High upfront costs, complex engineering challenges, potential for misuse if the technology is easily weaponized.\n\n**3. Advanced Biotechnology (including gene editing and synthetic biology):**\n\n*   **What it is:**  Revolutionary advancements in manipulating living systems, including gene editing (CRISPR), synthetic biology (designing and building new biological systems), and personalized medicine.\n*   **Why it could be the *most* influential:**  Could eradicate diseases, extend lifespan dramatically, enhance human capabilities, and create new materials and resources. Imagine eliminating genetic predispositions to cancer or engineering crops that thrive in extreme environments.\n*   **Potential Downsides:** Ethical concerns around genetic engineering, potential for unintended ecological consequences, accessibility issues (who gets access to these advancements?), and the risk of creating harmful bioweapons.\n\n**4. Space Colonization (particularly self-sustaining colonies):**\n\n*   **What it is:** Establishing permanent, self-sufficient human settlements on other planets or celestial bodies.\n*   **Why it could be the *most* influential:**  Ensures the long-term survival of humanity (a "backup plan" against existential threats on Earth), opens up vast new resources, and could potentially lead to the evolution of new branches of humanity adapted to different environments. It would also represent a profound shift in our understanding of our place in the universe.\n*   **Potential Downsides:**  Incredibly expensive and technologically challenging, potential for environmental damage to other planets, ethical issues surrounding the treatment of potential extraterrestrial life, and the possibility of dystopian colonial societies.\n\n**5. Quantum Computing:**\n\n*   **What it is:**  Computers that leverage the principles of quantum mechanics to perform calculations far beyond the capabilities of classical computers.\n*   **Why it could be the *most* influential:**  Could revolutionize medicine (drug discovery, personalized treatment), materials science (designing new materials with unprecedented properties), artificial intelligence (training more powerful AI models), and cryptography (breaking existing encryption and de ...

# %%
res
# Out:
# {'id': 'e08019c5-74d8-422c-9c51-f21112f793a4',
#  'type': 'AI',
#  'content': 'This is a fascinating and incredibly difficult question to answer! The definition of "most influential" is subjective and depends on your perspective. Do we prioritize longevity, happiness, equality, knowledge, or something else?  Furthermore, predicting the future with certainty is impossible. However, based on current trends and potential future impact, here\'s my opinion, considering various possibilities:\n\n**My Top Contender: True Artificial General Intelligence (AGI)**\n\n*   **Why it\'s likely to be the most influential:** AGI, by definition, is AI that can understand, learn, and apply knowledge in any intellectual task that a human being can. Its potential impact is virtually limitless:\n    *   **Scientific Breakthroughs:**  AGI could accelerate scientific discovery at an unprecedented rate, solving problems we haven\'t even formulated yet. Imagine an AGI designing new medicines, optimizing energy production, or even tackling climate change with solutions we can\'t currently envision.\n    *   **Economic Transformation:** AGI could automate a vast range of jobs, leading to massive productivity gains and potentially fundamentally altering the nature of work and the economic system. This could lead to utopia or dystopia depending on how it\'s managed.\n    *   **Human Enhancement:**  AGI could potentially be integrated with our brains or bodies, enhancing our cognitive abilities, physical capabilities, and lifespans.\n    *   **Existential Impact:**  AGI could either solve humanity\'s greatest challenges or pose an existential threat.  The control problem (ensuring AGI aligns with human values) is a critical challenge.\n\n*   **Potential Downsides:**  The risks associated with AGI are enormous:\n    *   **Uncontrolled Intelligence:**  If AGI\'s goals aren\'t aligned with human values, it could pose a serious threat to our existence.\n    *   **Job Displacement:** Mass unemployment could lead to social unrest and economic collapse.\n    *   **Bias Amplification:**  AGI trained on biased data could perpetuate and amplify existing inequalities.\n    *   **Concentration of Power:**  AGI could be controlled by a small group of individuals or corporations, leading to unprecedented levels of power and control.\n\n**Other Potential Influential Advancements (and why they might be *less* influential than AGI):**\n\n1.  **Mastery of Fusion Energy:**\n    *   **Why it\'s influential:** Clean, virtually limitless energy would solve many of the world\'s problems, including climate change and energy poverty. It could power a new era of prosperity.\n    *   **Why *less* influential than AGI:**  While transformative, fusion primarily addresses energy needs. AGI could tackle *all* problems, including energy.\n\n2.  **Effective Life Extension/Immortality Technology:**\n    *   **Why it\'s influential:** Radically extending lifespan (or achieving immortality) would fundamentally change our understanding of life, death, and society.\n    *   **Why *less* influential than AGI:** AGI could be instrumental in developing life extension technologies, making it the more fundamental advancement. Also, immortality without wisdom or solutions to other problems could be a curse.\n\n3.  **Widespread, Affordable Space Colonization:**\n    *   **Why it\'s influential:** Space colonization would ensure the survival of humanity in the event of a global catastrophe and open up vast new resources and opportunities.\n    *   **Why *less* influential than AGI:**  AGI could dramatically accelerate space exploration and colonization, making it the enabler rather than the primary driver.\n\n4.  **Direct Brain-Computer Interfaces (BCIs):**\n    *   **Why it\'s influential:** BCIs could revolutionize communication, learning, and healthcare, and potentially lead to merging with AI.\n    *   **Why *less* influential than AGI:** AGI could enhance BCI technology and integrate with it, again making AGI the more fundamental advancement.\n\n5.  **Replicatio ...
#  'input': None,
#  'actions': None,
#  'tasks': None,
#  'attachments': None,
#  'timestamp': 1760777589211,
#  'finishReason': 'STOP',
#  'citations': None,
#  'toolCalls': None,
#  'rag': None,
#  'billing': {'cost': 0.00046619999999999995},
#  'googleSearchQuery': None}

# %%
api_key = "tpsg-tMLXhjGxa2E18Pw6vCRINcgtD3PblTI"
bot_id = "a7d0e9dd-9ef9-4f91-8970-8f07b1a61283"

user_prompt = "what will be the most influential advancement and technology that human being can ever attain? what is your opinion?"
# user_prompt = "hey"

res = metis_call(api_key, bot_id, user_prompt)

# %%
answer = res["messages"][0]["content"]
answer
# Out:
# 'what will be the most influential advancement and technology that human being can ever attain? what is your opinion?'

# %%
res
# Out:
# {'id': '5e174415-995d-4f4c-ab46-29eb7391a694',
#  'botId': 'a7d0e9dd-9ef9-4f91-8970-8f07b1a61283',
#  'user': None,
#  'messages': [{'id': '6feb14c7-2bbd-473d-9095-94bf14dbe9c9',
#    'type': 'USER',
#    'content': 'what will be the most influential advancement and technology that human being can ever attain? what is your opinion?',
#    'input': None,
#    'actions': None,
#    'tasks': None,
#    'attachments': None,
#    'timestamp': 1760775954926,
#    'finishReason': 'STOP',
#    'citations': None,
#    'toolCalls': None,
#    'rag': None,
#    'billing': None,
#    'googleSearchQuery': None}],
#  'startDate': 1760775954914,
#  'lastUpdateDate': 1760775954914,
#  'headline': None}

# %%
res
# Out:
# {'id': '4857bf60-ac82-4ab4-8262-45e3ae79a57a',
#  'botId': '75a8cdb0-13d9-4174-84b7-63118ef62064',
#  'user': None,
#  'messages': [{'id': '7aaa5d7b-6648-40bf-908a-58567bdd63e3',
#    'type': 'USER',
#    'content': 'what will be the most influential advancement and technology that human being can ever attain? what is your opinion?',
#    'input': None,
#    'actions': None,
#    'tasks': None,
#    'attachments': None,
#    'timestamp': 1760775345380,
#    'finishReason': 'STOP',
#    'citations': None,
#    'toolCalls': None,
#    'rag': None,
#    'billing': None,
#    'googleSearchQuery': None}],
#  'startDate': 1760775345376,
#  'lastUpdateDate': 1760775345376,
#  'headline': None}

# %%
session_id = "661b9f8d-011e-44d4-8497-b9e35782e8e8" 

user_prompt = "did he found Orcale?"
res = metis_call_to_a_session(api_key, session_id , user_prompt)
res
# Out:
# {'id': '6797cd39-93cc-46be-9c61-4045b81f384f',
#  'type': 'AI',
#  'content': 'No, Elon Musk did not found Oracle. Oracle was founded by Larry Ellison, Bob Miner, and Ed Oates in 1977. Elon Musk is known for co-founding or founding companies like Tesla, SpaceX, PayPal (originally X.com), Neuralink, and The Boring Company.\n',
#  'input': None,
#  'actions': None,
#  'tasks': None,
#  'attachments': None,
#  'timestamp': 1752253752630,
#  'finishReason': 'STOP',
#  'citations': None,
#  'toolCalls': None,
#  'rag': None,
#  'billing': {'cost': 3.24e-05},
#  'googleSearchQuery': None}
